# %%
# Importamos libreria
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Creamos un grafio utilizando plt.plot()
plt.plot()
# Out:
# []

# %%
# Graficamos una lista de numeros
a= [1,5,3,8,15]
plt.plot(a)

# %%
# Creamos dos listas, x e y. Llenamos a las lista x de valores del 1 al 100
# Los valores e y van a equivaler al cuadrado del respectivo valor en x con el mismo indice
x = list(range(101))
y = []
for numero in x:
  y.append(numero**2)

# %%
# Graficamos ambas listas creadas
plt.plot(x, y)

# %% [markdown]
# Hay otra forma de crear graficos en Matplotlib, utilizando el metodo orientado a objeto (OO)

# %%
# Creamos el grafico utilizando plt.subplots()
fig, ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# Veamos un flujo completo de trabajo

# %%
# Importar y preparar la libreria
import matplotlib.pyplot as plt
# %matplotlib inline

# Preparar los datos
x = list(range(101))
y = []
for num in x:
  y.append(num**2)

# Preparamos el area del grafico (fig) y el gráfico en sí (ax) utilizando plt.subplots()
fig, ax = plt.subplots()

# Añadir los datos al gráfico
ax.plot(x,y)

# personalizamos el grafico añadiendo título al gráfico y a los ejes x e y
ax.set(title= 'Grafico casos de COVID-19', xlabel= 'dias', ylabel= 'cant casos')

# Guardamos nuestro gráficos empleado fig.savefig()
fig.savefig('/ejemplo-grafico-covid.png')

# %% [markdown]
# Veamos ahora un grafico de dispersion

# %%
# Creamos un nuevo set de datos utilizando la libreria Numpy
import numpy as np

x_1 = np.linspace(0,100, 20)
y_1 = x_1 ** 2

# Creamos el grafico de dispersion de x vs y
fig, ax = plt.subplots()
ax.scatter(x_1, y_1)

# %%
# Visualizamos ahora la funcion seno, utilizando np.sin(X)

fig, ax = plt.subplots()

x_2 = np.linspace(-10, 10, 100)
y_2 = np.sin(x_2)

ax.scatter(x_2, y_2)

# %% [markdown]
# Veamos graficos de barra

# %%
# Creemos un diccionario con tres platos y su respectivo precio
# Las Claves del diccionario serán los nombres de las comidas, y los valores asociados, su precio
comidas = {'lasagna': 350,
           'sopa': 100,
           'bife': 500}

# %%
#Crearemos un grafico de barras donde el eje x está formado por las claves del diccionario,
#y el eje y contiene los valores

fig, ax = plt.subplots()

ax.bar(comidas.keys(), comidas.values())

# Añadirtemos titulos
ax.set(title= 'Comparacion precios', xlabel= 'Comida', ylabel= 'Precio')
# Out:
# [Text(0.5, 1.0, 'Comparacion precios'),
#  Text(0.5, 0, 'Comida'),
#  Text(0, 0.5, 'Precio')]

# %%
# Veamos el grafico en horizontal

fig, ax = plt.subplots()

ax.barh(list(comidas.keys()), list(comidas.values()))

ax.set(title= 'Comparacion precios', xlabel= 'Precio', ylabel= 'Comida')
# Out:
# [Text(0.5, 1.0, 'Comparacion precios'),
#  Text(0.5, 0, 'Precio'),
#  Text(0, 0.5, 'Comida')]

# %%
# Creamos una distribucion de 1000 valores aleatorios distribuidos normalmente
# usamos randn para generar una distribucion normal
x = np.random.randn(1000)

# Creamos histograma
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  9.,  31.,  89., 171., 221., 228., 153.,  76.,  19.,   3.]),
#  array([-2.92864439, -2.33191037, -1.73517635, -1.13844234, -0.54170832,
#          0.0550257 ,  0.65175972,  1.24849373,  1.84522775,  2.44196177,
#          3.03869579]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Varios graficos

# %%
# Creamos una figura con 4 subgráficos (2 por filas)
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(nrows=2, ncols= 2, figsize= (10,5))

# %%
# Creamos la misma disposición de gráficos, con un tamaño de figura de  10x5
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(nrows=2, ncols= 2, figsize= (10,5))

# Para nuestro primer grafico, tomamos el conjunto x_1, y_1, y generamos un grafico de lineas
ax1.plot(x_1, y_1)

# Para nuestro segundo grafico, tomamos el conjunto x_2, y_2 y generamos un grafico de dispersion
ax2.scatter(x_2, y_2)

# Creamos un grafico con los precios de tres comidas en la esquina inferior izquierda
ax3.bar(comidas.keys(), comidas.values())

# El grafico de la esquina inferior derecha sera un histograma de valores aleatorios con distribucion normal
ax4.hist(x)
# Out:
# (array([  9.,  31.,  89., 171., 221., 228., 153.,  76.,  19.,   3.]),
#  array([-2.92864439, -2.33191037, -1.73517635, -1.13844234, -0.54170832,
#          0.0550257 ,  0.65175972,  1.24849373,  1.84522775,  2.44196177,
#          3.03869579]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Matplotlib tiene varios estilos disponibles

# %%
# Verificamos todos los estilos disponibles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Cambiamos el estilo predeterminado por 'seaborn-whitegrid
plt.style.use('seaborn-whitegrid')

# %%
# Creamos la misma disposición de gráficos, con un tamaño de figura de  10x5
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(nrows=2, ncols= 2, figsize= (10,5))

# Para nuestro primer grafico, tomamos el conjunto x_1, y_1, y generamos un grafico de lineas
ax1.plot(x_1, y_1, color= '#fcba03')

# Para nuestro segundo grafico, tomamos el conjunto x_2, y_2 y generamos un grafico de dispersion
ax2.scatter(x_2, y_2, color= '#fcba03')

# Creamos un grafico con los precios de tres comidas en la esquina inferior izquierda
ax3.bar(comidas.keys(), comidas.values(), color= '#03c6fc')

# El grafico de la esquina inferior derecha sera un histograma de valores aleatorios con distribucion normal
ax4.hist(x, color= '#fc036b')
# Out:
# (array([  9.,  31.,  89., 171., 221., 228., 153.,  76.,  19.,   3.]),
#  array([-2.92864439, -2.33191037, -1.73517635, -1.13844234, -0.54170832,
#          0.0550257 ,  0.65175972,  1.24849373,  1.84522775,  2.44196177,
#          3.03869579]),
#  <BarContainer object of 10 artists>)
