# %%
#importar pandas
import pandas as pd

# %%
# Creamos una serie de numerosy hallamos su media
numeros = pd.Series([1,2,3,5,67,35,235,62])
numeros.mean()
# Out:
# 51.25

# %%
# suma
numeros.sum()
# Out:
# 410

# %%
# Creamos una serie de tres colores diferentes
colores = pd.Series(['rojo', 'amarillo', 'verde'])

# %%
# Visualizamos la serie creada
colores
# Out:
# 0        rojo
# 1    amarillo
# 2       verde
# dtype: object

# %%
# Creamos una serie con tipos de autos y la visualizamos
tipos_autos = pd.Series(['Sedan', 'SUV', 'Pick Up'])
tipos_autos
# Out:
# 0      Sedan
# 1        SUV
# 2    Pick Up
# dtype: object

# %%
# Combinamos las series de tipo de autos y colores en un Dataframe
tabla_autos = pd.DataFrame({'Tipo de Auto': tipos_autos, 'Color': colores})
tabla_autos
# Out:
#   Tipo de Auto     Color
# 0        Sedan      rojo
# 1          SUV  amarillo
# 2      Pick Up     verde

# %%
# Conectamos el cuaderno con nuestro drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar "ventas-autos.csv" y convertirlo en un nuevo DataFrame
ventas_autos = pd.read_csv('/content/drive/MyDrive/Colab/6.1 ventas-autos.csv')
ventas_autos
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 0     Toyota  Blanco       150043        4    $4,000.00
# 1      Honda    Rojo        87899        4    $5,000.00
# 2     Toyota    Azul        32549        3    $7,000.00
# 3        BMW   Negro        11179        5   $22,000.00
# 4     Nissan  Blanco       213095        4    $3,500.00
# 5     Toyota    Rojo        99213        4    $4,500.00
# 6      Honda  Blanco        45698        4    $7,500.00
# 7      Honda  Blanco        54738        4    $7,000.00
# 8     Toyota  Blanco        60000        4    $6,250.00
# 9     Nissan    Rojo        31600        4    $9,700.00

# %%
# Analizamos tipos de datos
ventas_autos.dtypes
# Out:
# Fabricante      object
# Color           object
# Kilometraje      int64
# Puertas          int64
# Precio (USD)    object
# dtype: object

# %%
# Apliquemos estadistica descriptiva
ventas_autos.describe()
# Out:
#          Kilometraje    Puertas
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Informacion sobre nuestro dataframe
ventas_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Fabricante    10 non-null     object
#  1   Color         10 non-null     object
#  2   Kilometraje   10 non-null     int64
#  3   Puertas       10 non-null     int64
#  4   Precio (USD)  10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Listamos los nombres de las columnas de nuestros Dataframe
ventas_autos.columns
# Out:
# Index(['Fabricante', 'Color', 'Kilometraje', 'Puertas', 'Precio (USD)'], dtype='object')

# %%
# Averiguamos el largo de nuestro dataframe
len(ventas_autos)
# Out:
# 10

# %%
# Mostramos las primeras 5 filas de nuestro dataframe
ventas_autos.head()
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 0     Toyota  Blanco       150043        4    $4,000.00
# 1      Honda    Rojo        87899        4    $5,000.00
# 2     Toyota    Azul        32549        3    $7,000.00
# 3        BMW   Negro        11179        5   $22,000.00
# 4     Nissan  Blanco       213095        4    $3,500.00

# %%
# Mostramos las primeras 7 filas
ventas_autos.head(7)
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 0     Toyota  Blanco       150043        4    $4,000.00
# 1      Honda    Rojo        87899        4    $5,000.00
# 2     Toyota    Azul        32549        3    $7,000.00
# 3        BMW   Negro        11179        5   $22,000.00
# 4     Nissan  Blanco       213095        4    $3,500.00
# 5     Toyota    Rojo        99213        4    $4,500.00
# 6      Honda  Blanco        45698        4    $7,500.00

# %%
# Mostramos las ultimas 5 filas
ventas_autos.tail()
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 5     Toyota    Rojo        99213        4    $4,500.00
# 6      Honda  Blanco        45698        4    $7,500.00
# 7      Honda  Blanco        54738        4    $7,000.00
# 8     Toyota  Blanco        60000        4    $6,250.00
# 9     Nissan    Rojo        31600        4    $9,700.00

# %%
# Utilizamos .loc para seleccionar la fila de indice 3 del DataFrame
ventas_autos.loc[3]
# Out:
# Fabricante         Toyota
# Color                Azul
# Kilometraje         32549
# Puertas                 3
# Precio (USD)    $7,000.00
# Name: 2, dtype: object

# %%
# Utilizamos .iloc para seleccionar las filas 3, 7 y 9
ventas_autos.iloc[[3,7,9]]
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 3        BMW   Negro        11179        5   $22,000.00
# 7      Honda  Blanco        54738        4    $7,000.00
# 9     Nissan    Rojo        31600        4    $9,700.00

# %%
# Selecccionar columna kilometraje
ventas_autos['Kilometraje']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Kilometraje, dtype: int64

# %%
# Econtrar el valor medio de la columna kilometraje
ventas_autos['Kilometraje'].mean()
# Out:
# 78601.4

# %%
# Seleccionar aquellas columnas que tengan valores superiores a 100,000 kilometros en la columna kilometraje
ventas_autos[ventas_autos['Kilometraje'] > 100000]
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 0     Toyota  Blanco       150043        4    $4,000.00
# 4     Nissan  Blanco       213095        4    $3,500.00

# %%
# Creamos una tabla cruzada de doble entrada entre fabricante y cantidad de puertas
pd.crosstab(ventas_autos['Fabricante'], ventas_autos['Puertas'])
# Out:
# Puertas     3  4  5
# Fabricante
# BMW         0  0  1
# Honda       0  3  0
# Nissan      0  2  0
# Toyota      1  3  0

# %%
# Agrupamos columnas por faricantes y buscamos el valor medio de las columnas numericas
ventas_autos.groupby('Fabricante').mean()
# Out:
#               Kilometraje  Puertas
# Fabricante
# BMW          11179.000000     5.00
# Honda        62778.333333     4.00
# Nissan      122347.500000     4.00
# Toyota       85451.250000     3.75

# %%
from ast import increment_lineno
# Importamos Matplotlib y creamos un grafico con los valores de la columna kilometrajes
import matplotlib.pyplot as plt
# %matplotlib inline

ventas_autos['Kilometraje'].plot()

# %%
# Probar con otro tipo de grafico
ventas_autos['Kilometraje'].hist()

# %%
# Creamos grafico de precios. Se debe modificar los tipos de datos
ventas_autos['Precio (USD)'] = ventas_autos['Precio (USD)'].str.replace("[\,\$\.]", "")
ventas_autos['Precio (USD)'] = ventas_autos['Precio (USD)'].astype(int)/100
ventas_autos
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   Fabricante   Color  Kilometraje  Puertas  Precio (USD)
# 0     Toyota  Blanco       150043        4        4000.0
# 1      Honda    Rojo        87899        4        5000.0
# 2     Toyota    Azul        32549        3        7000.0
# 3        BMW   Negro        11179        5       22000.0
# 4     Nissan  Blanco       213095        4        3500.0
# 5     Toyota    Rojo        99213        4        4500.0
# 6      Honda  Blanco        45698        4        7500.0
# 7      Honda  Blanco        54738        4        7000.0
# 8     Toyota  Blanco        60000        4        6250.0
# 9     Nissan    Rojo        31600        4        9700.0

# %%
ventas_autos['Precio (USD)'].hist()
